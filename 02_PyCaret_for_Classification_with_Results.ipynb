# %% [markdown]
# <a href="https://colab.research.google.com/github/psrana/Machine-Learning-using-PyCaret/blob/main/02_PyCaret_for_Classification_with_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **PyCaret for Classification**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self learning resource**
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html" target="_blank"> Click Here</a>**
#
# 2. Documentation on Pycaret-Classification: **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html" target="_blank"> Click Here </a>**
#
# ---
#
# ### **In this tutorial we will learn:**
#
# - Getting Data
# - Setting up Environment
# - Create Model
# - Tune Model
# - Plot Model
# - Finalize Model
# - Predict Model
# - Save / Load Model
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!
# The syntax of the command is incorrect.

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.6'

# %% [markdown]
# ---
# # **1. Classification: Basics**
# ---
# ### **1.1 Get the list of datasets available in pycaret (Total Datasets = 55)**

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ---
# ### **1.2 Get the "diabetes" dataset (Step-I)**
# ---

# %%
diabetesDataSet = get_data("diabetes")    # SN is 7
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# ---
# ### **1.3 Parameter setting for all models (Step-II)**
# ---

# %%
from pycaret.classification import *
s = setup(data=diabetesDataSet, target='Class variable', silent=True)

# Other Parameters:
# train_size = 0.7
# data_split_shuffle = False
# Out:
# <style type="text/css">
# #T_2dbec_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2dbec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dbec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2dbec_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2dbec_row0_col1" class="data row0 col1" >4997</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2dbec_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2dbec_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2dbec_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_2dbec_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2dbec_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_2dbec_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2dbec_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_2dbec_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2dbec_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_2dbec_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2dbec_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_2dbec_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2dbec_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_2dbec_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2dbec_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_2dbec_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2dbec_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_2dbec_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2dbec_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_2dbec_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2dbec_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_2dbec_row11_col1" class="data row11 col1" >(537, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2dbec_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_2dbec_row12_col1" class="data row12 col1" >(231, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2dbec_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_2dbec_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2dbec_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_2dbec_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2dbec_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_2dbec_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2dbec_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_2dbec_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2dbec_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_2dbec_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2dbec_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_2dbec_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2dbec_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_2dbec_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2dbec_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_2dbec_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2dbec_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_2dbec_row21_col1" class="data row21 col1" >339e</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2dbec_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_2dbec_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2dbec_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_2dbec_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2dbec_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_2dbec_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2dbec_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_2dbec_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_2dbec_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_2dbec_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_2dbec_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_2dbec_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_2dbec_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_2dbec_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_2dbec_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_2dbec_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2dbec_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_2dbec_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_2dbec_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <t

# %% [markdown]
# ---
# ### **1.4 Run all models (Step-III)**
# ---

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_13866_ th {
#   text-align: left;
# }
# #T_13866_row0_col0, #T_13866_row0_col3, #T_13866_row0_col4, #T_13866_row0_col5, #T_13866_row1_col0, #T_13866_row1_col1, #T_13866_row1_col2, #T_13866_row1_col3, #T_13866_row1_col4, #T_13866_row1_col5, #T_13866_row1_col6, #T_13866_row1_col7, #T_13866_row2_col0, #T_13866_row2_col1, #T_13866_row2_col2, #T_13866_row2_col3, #T_13866_row2_col5, #T_13866_row2_col6, #T_13866_row2_col7, #T_13866_row3_col0, #T_13866_row3_col1, #T_13866_row3_col2, #T_13866_row3_col3, #T_13866_row3_col4, #T_13866_row3_col6, #T_13866_row3_col7, #T_13866_row4_col0, #T_13866_row4_col1, #T_13866_row4_col2, #T_13866_row4_col3, #T_13866_row4_col4, #T_13866_row4_col5, #T_13866_row4_col6, #T_13866_row4_col7, #T_13866_row5_col0, #T_13866_row5_col1, #T_13866_row5_col2, #T_13866_row5_col3, #T_13866_row5_col4, #T_13866_row5_col5, #T_13866_row5_col6, #T_13866_row5_col7, #T_13866_row6_col0, #T_13866_row6_col1, #T_13866_row6_col2, #T_13866_row6_col3, #T_13866_row6_col4, #T_13866_row6_col5, #T_13866_row6_col6, #T_13866_row6_col7, #T_13866_row7_col0, #T_13866_row7_col1, #T_13866_row7_col2, #T_13866_row7_col3, #T_13866_row7_col4, #T_13866_row7_col5, #T_13866_row7_col6, #T_13866_row7_col7, #T_13866_row8_col0, #T_13866_row8_col1, #T_13866_row8_col2, #T_13866_row8_col3, #T_13866_row8_col4, #T_13866_row8_col5, #T_13866_row8_col6, #T_13866_row8_col7, #T_13866_row9_col0, #T_13866_row9_col1, #T_13866_row9_col2, #T_13866_row9_col3, #T_13866_row9_col4, #T_13866_row9_col5, #T_13866_row9_col6, #T_13866_row9_col7, #T_13866_row10_col0, #T_13866_row10_col1, #T_13866_row10_col2, #T_13866_row10_col3, #T_13866_row10_col4, #T_13866_row10_col5, #T_13866_row10_col6, #T_13866_row10_col7, #T_13866_row11_col0, #T_13866_row11_col1, #T_13866_row11_col2, #T_13866_row11_col3, #T_13866_row11_col4, #T_13866_row11_col5, #T_13866_row11_col6, #T_13866_row11_col7, #T_13866_row12_col0, #T_13866_row12_col1, #T_13866_row12_col2, #T_13866_row12_col3, #T_13866_row12_col4, #T_13866_row12_col5, #T_13866_row12_col6, #T_13866_row12_col7, #T_13866_row13_col0, #T_13866_row13_col1, #T_13866_row13_col2, #T_13866_row13_col3, #T_13866_row13_col4, #T_13866_row13_col5, #T_13866_row13_col6, #T_13866_row13_col7, #T_13866_row14_col0, #T_13866_row14_col1, #T_13866_row14_col2, #T_13866_row14_col4, #T_13866_row14_col5, #T_13866_row14_col6, #T_13866_row14_col7 {
#   text-align: left;
# }
# #T_13866_row0_col1, #T_13866_row0_col2, #T_13866_row0_col6, #T_13866_row0_col7, #T_13866_row2_col4, #T_13866_row3_col5, #T_13866_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_13866_row0_col8, #T_13866_row1_col8, #T_13866_row2_col8, #T_13866_row3_col8, #T_13866_row4_col8, #T_13866_row5_col8, #T_13866_row6_col8, #T_13866_row7_col8, #T_13866_row8_col8, #T_13866_row9_col8, #T_13866_row10_col8, #T_13866_row11_col8, #T_13866_row13_col8, #T_13866_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_13866_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_13866_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13866_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_13866_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_13866_row0_col1" class="data row0 col1" >0.7655</td>
#       <td id="T_13866_row0_col2" class="data row0 col2" >0.8143</td>
#       <td id="T_13866_row0_col3" class="data row0 col3" >0.5743</td>
#       <td id="T_13866_row0_col4" class="data row0 col4" >0.6948</td>
#       <td id="T_13866_row0_col5" class="data row0 col5" >0.6228</td>
#       <td id="T_13866_row0_col6" class="data row0 col6" >0.4568</td>
#       <td id="T_13866_row0_col7" class="data row0 col7" >0.4647</td>
#       <td id="T_13866_row0_col8" class="data row0 col8" >1.7170</td>
#     </tr>
#     <tr>
#       <th id="T_13866_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_13866_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_13866_row1_col1" class="data row1 col1" >0.7618</td>
#       <td id="T_13866_row1_col2" class="data row1 col2" >0.8077</td>
#       <td id="T_13866_row1_col3" class="data row1 col3" >0.5781</td>
#       <td id="T_13866_row1_col4" class="data row1 col4" >0.6857</td>
#       <td id="T_13866_row1_col5" class="data row1 col5" >0.6189</td>
#       <td id="T_13866_row1_col6" class="data row1 col6" >0.4495</td>
#       <td id="T_13866_row1_col7" class="data row1 col7" >0.4582</td>
#       <td id="T_13866_row1_col8" class="data row1 col8" >0.2190</td>
#     </tr>
#     <tr>
#       <th id="T_13866_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_13866_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_13866_row2_col1" class="data row2 col1" >0.7581</td>
#       <td id="T_13866_row2_col2" class="data row2 col2" >0.8062</td>
#       <td id="T_13866_row2_col3" class="data row2 col3" >0.4968</td>
#       <td id="T_13866_row2_col4" class="data row2 col4" >0.7147</td>
#       <td id="T_13866_row2_col5" class="data row2 col5" >0.5802</td>
#       <td id="T_13866_row2_col6" class="data row2 col6" >0.4200</td>
#       <td id="T_13866_row2_col7" class="data row2 col7" >0.4362</td>
#       <td id="T_13866_row2_col8" class="data row2 col8" >0.1430</td>
#     </tr>
#     <tr>
#       <th id="T_13866_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_13866_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_13866_row3_col1" class="data row3 col1" >0.7579</td>
#       <td id="T_13866_row3_col2" class="data row3 col2" >0.8062</td>
#       <td id="T_13866_row3_col3" class="data row3 col3" >0.5953</td>
#       <td id="T_13866_row3_col4" class="data row3 col4" >0.6733</td>
#       <td id="T_13866_row3_col5" class="data row3 col5" >0.6296</td>
#       <td id="T_13866_row3_col6" class="data row3 col6" >0.4511</td>
#       <td id="T_13866_row3_col7" class="data row3 col7" >0.4548</td>
#       <td id="T_13866_row3_col8" class="data row3 col8" >1.5270</td>
#     </tr>
#     <tr>
#       <th id="T_13866_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_13866_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_13866_row4_col1" class="data row4 col1" >0.7561</td>
#       <td id="T_13866_row4_col2" class="data row4 col2" >0.8102</td>
#       <td id="T_13866_row4_col3" class="data row4 col3" >0.5474</td>
#       <td id="T_13866_row4_col4" class="data row4 col4" >0.6837</td>
#       <td id="T_13866_row4_col5" class="data row4 col5" >0.6029</td>
#       <td id="T_13866_row4_col6" class="data row4 col6" >0.4319</td>
#       <td id="T_13866_row4_col7" class="data row4 col7" >0.4402</td>
#       <td id="T_13866_row4_col8" class="data row4 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_13866_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_13866_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_13866_row5_col1" class="data row5 col1" >0.7524</td>
#       <td id="T_13866_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_13866_row5_col3" class="data row5 col3" >0.5365</td>
#       <td id="T_13866_row5_col4" class="data row5 col4" >0.6796</td>
#       <td id="T_13866_row5_col5" class="data row5 col5" >0.5943</td>
#       <td id="T_13866_row5_col6" class="data row5 col6" >0.4217</td>
#       <td id="T_13866_row5_col7" class="data row5 col7" >0.4306</td>
#       <td id="T_13866_row5_col8" class="data row5

# %% [markdown]
# ---
# ### **1.5 "Three line of code" for model comparison for "Diabetes" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_783e2_row3_col1" class="data row3 col1" >0.7575</td>
#       <td id="T_783e2_row3_col2" class="data row3 col2" >0.8042</td>
#       <td id="T_783e2_row3_col3" class="data row3 col3" >0.6211</td>
#       <td id="T_783e2_row3_col4" class="data row3 col4" >0.6660</td>
#       <td id="T_783e2_row3_col5" class="data row3 col5" >0.6395</td>
#       <td id="T_783e2_row3_col6" class="data row3 col6" >0.4582</td>
#       <td id="T_783e2_row3_col7" class="data row3 col7" >0.4612</td>
#       <td id="T_783e2_row3_col8" class="data row3 col8" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_783e2_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_783e2_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_783e2_row4_col1" class="data row4 col1" >0.7558</td>
#       <td id="T_783e2_row4_col2" class="data row4 col2" >0.8181</td>
#       <td id="T_783e2_row4_col3" class="data row4 col3" >0.5737</td>
#       <td id="T_783e2_row4_col4" class="data row4 col4" >0.6902</td>
#       <td id="T_783e2_row4_col5" class="data row4 col5" >0.6202</td>
#       <td id="T_783e2_row4_col6" class="data row4 col6" >0.4441</td>
#       <td id="T_783e2_row4_col7" class="data row4 col7" >0.4521</td>
#       <td id="T_783e2_row4_col8" class="data row4 col8" >0.1840</td>
#     </tr>
#     <tr>
#       <th id="T_783e2_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_783e2_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_783e2_row5_col1" class="data row5 col1" >0.7558</td>
#       <td id="T_783e2_row5_col2" class="data row5 col2" >0.8325</td>
#       <td id="T_783e2_row5_col3" class="data row5 col3" >0.5947</td>
#       <td id="T_783e2_row5_col4" class="data row5 col4" >0.6827</td>
#       <td id="T_783e2_row5_col5" class="data row5 col5" >0.6254</td>
#       <td id="T_783e2_row5_col6" class="data row5 col6" >0.4478</td>
#       <td id="T_783e2_row5_col7" class="data row5 col7" >0.4582</td>
#       <td id="T_783e2_row5_col8" cl

# %% [markdown]
# ---
# ### **1.6 "Three line of code" for model comparison for "Cancer" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

cancerDataSet = get_data("cancer")
setup(data = cancerDataSet, target='Class', silent=True)
cm = compare_models()
# Out:
# <style type="text/css">
# #T_b86dd_ th {
#   text-align: left;
# }
# #T_b86dd_row0_col0, #T_b86dd_row0_col3, #T_b86dd_row0_col4, #T_b86dd_row0_col7, #T_b86dd_row1_col0, #T_b86dd_row1_col1, #T_b86dd_row1_col2, #T_b86dd_row1_col3, #T_b86dd_row1_col4, #T_b86dd_row1_col5, #T_b86dd_row1_col6, #T_b86dd_row2_col0, #T_b86dd_row2_col1, #T_b86dd_row2_col2, #T_b86dd_row2_col3, #T_b86dd_row2_col4, #T_b86dd_row2_col5, #T_b86dd_row2_col6, #T_b86dd_row2_col7, #T_b86dd_row3_col0, #T_b86dd_row3_col1, #T_b86dd_row3_col2, #T_b86dd_row3_col3, #T_b86dd_row3_col4, #T_b86dd_row3_col5, #T_b86dd_row3_col6, #T_b86dd_row3_col7, #T_b86dd_row4_col0, #T_b86dd_row4_col1, #T_b86dd_row4_col2, #T_b86dd_row4_col3, #T_b86dd_row4_col4, #T_b86dd_row4_col5, #T_b86dd_row4_col6, #T_b86dd_row4_col7, #T_b86dd_row5_col0, #T_b86dd_row5_col1, #T_b86dd_row5_col2, #T_b86dd_row5_col3, #T_b86dd_row5_col4, #T_b86dd_row5_col5, #T_b86dd_row5_col6, #T_b86dd_row5_col7, #T_b86dd
row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_b86dd_row4_col3" class="data row4 col3" >0.9186</td>
#       <td id="T_b86dd_row4_col4" class="data row4 col4" >0.9623</td>
#       <td id="T_b86dd_row4_col5" class="data row4 col5" >0.9364</td>
#       <td id="T_b86dd_row4_col6" class="data row4 col6" >0.9031</td>
#       <td id="T_b86dd_row4_col7" class="data row4 col7" >0.9074</td>
#       <td id="T_b86dd_row4_col8" class="data row4 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_b86dd_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_b86dd_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b86dd_row5_col1" class="data row5 col1" >0.9540</td>
#       <td id="T_b86dd_row5_col2" class="data row5 col2" >0.9913</td>
#       <td id="T_b86dd_row5_col3" class="data row5 col3" >0.9301</td>
#       <td id="T_b86dd_row5_col4" class="data row5 col4" >0.9475</td>
#       <td id="T_b86dd_row5_col5" class="data row5 col5" >0.9353</td>
#       <td id="T_b86dd_row5_col6" class="data row5 col6" >0.8997</td>
#       <td id="T_b86dd_row5_col7" class="data row5 col7" >0.9036</td>
#       <td id="T_b86dd_row5_col8" class="data row5 col8" >0.0660</td>

# %% [markdown]
# ---
# # **2. Classification: working with user dataset**
# ---
# ### **2.1 Download the "diabetes" dataset to local system**
# ---

# %%
diabetesDataSet.to_csv("diabetesDataSet.csv", index=False)

from google.colab import files
files.download('diabetesDataSet.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-95e95aa8e789> in <module>
#       1 diabetesDataSet.to_csv("diabetesDataSet.csv", index=False)
#       2
# ----> 3 from google.colab import files
#       4 files.download('diabetesDataSet.csv')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ---
# ### **2.2 Uploading "user file" from user system**
# ---

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ---
# ### **2.3 "Read" the uploaded file**
# ---

# %%
import pandas as pd
myDataSet = pd.read_csv('diabetesDataSet (1).csv')
myDataSet.head()

# %% [markdown]
# ---
# ### **2.4 "Compare" the model performance**
# ---

# %%
from pycaret.classification import *

setup(data = myDataSet, target='Class variable', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **2.5 "Three line of code" for model comparison for "user dataset**
#
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine
# ---

# %%
from pycaret.classification import *
import pandas as pd

#myDataSet = pd.read_csv("myData.csv")
#s = setup(data = myDataSet, target='cancer', silent=True)
#cm = compare_models()

# %% [markdown]
# ---
# # **3. Classification: Apply "Data Preprocessing"**
# ---
#
# ### **3.1 Model performance using "Normalization"**

# %%
setup(data=diabetesDataSet, target='Class variable', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

#normalize_method = {zscore, minmax, maxabs, robust}

# %% [markdown]
# ---
# ### **3.2 Model performance using "Feature Selection"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()

#feature_selection_method = {classic, boruta}

# %% [markdown]
# ---
# ### **3.3 Model performance using "Outlier Removal"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **3.4 Model performance using "Transformation"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **3.5 Model performance using "PCA"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **3.6 Model performance using "Outlier Removal" + "Normalization"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, 
      normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **3.7 Model performance using "Outlier Removal" +  "Normalization" + "Transformation"**
# ---

# %%
setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, 
      normalize = True, normalize_method = 'zscore', 
      transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# ### **3.8 Explore more parameters of "setup()" on pycaret**
# ---
# - Explore setup() paramaeters in **Step 1.3**
# - **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html" target="_blank"> Click Here</a>** for more

# %% [markdown]
# ---
# # **4. Classification: More Operations**
# ---
# ### **4.1 Build a single model - "RandomForest"**

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

diabetesDataSet = get_data("diabetes")
setup(data=diabetesDataSet, target='Class variable', silent=True)

rfModel = create_model('rf')
# Explore more parameters

# %% [markdown]
# ---
# ### **4.2 Other available classification models**
# ---
# -	'ada' -	Ada Boost Classifier
# -	'dt' -	Decision Tree Classifier
# -	'et' -	Extra Trees Classifier
# -	'gbc' -	Gradient Boosting Classifier
# -	'knn' -	K Neighbors Classifier
# -	'lightgbm' -	Light Gradient Boosting Machine
# -	'lda' -	Linear Discriminant Analysis
# -	'lr' -	Logistic Regression
# -	'nb' -	Naive Bayes
# -	'qda' -	Quadratic Discriminant Analysis
# -	'rf' -	Random Forest Classifier
# -	'ridge' -	Ridge Classifier
# -	'svm' -	SVM - Linear Kernel

# %% [markdown]
# ---
# ### **4.3 Explore more parameters of "create_model()" on pycaret**
# ---
#
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html#pycaret.classification.create_model" target="_blank"> Click Here</a>**

# %% [markdown]
# ---
# ### **4.4 Make prediction on the "new unseen dataset"**
# ---
# #### **Get the "new unseen dataset"**

# %%
# Select top 10 rows from diabetes dataset
newDataSet = get_data("diabetes").iloc[:10]

# %% [markdown]
# #### **Make prediction on "new unseen dataset"**

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions

# %% [markdown]
# ---
# ### **4.5 "Save" and "Download" the prediction result**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv", index=False)

from google.colab import files
files.download('NewPredictions.csv')

# %% [markdown]
# ---
# ### **4.6 "Save" the trained model**
# ---

# %%
sm = save_model(rfModel, 'rfModelFile')

# %% [markdown]
# ---
# ### **4.7 Download the "trained model file" to user local system**
# ---

# %%
from google.colab import files
files.download('rfModelFile.pkl')

# %% [markdown]
# ---
# ### **4.8  "Upload the trained model" --> "Load the model"  --> "Make the prediction" on "new unseen dataset"**
# ---
# ### **4.8.1 Upload the  "Trained Model"**

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ---
# ### **4.8.2 Load the "Model"**
# ---

# %%
rfModel = load_model('rfModelFile (1)')

# %% [markdown]
# ---
# ### **4.8.3 Make the prediction on "new unseen dataset"**
# ---

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions

# %% [markdown]
# ---
# # **5. Plot the trained model**
# ---
# **Following parameters can be plot for a trained model**
# *   Area Under the Curve         - 'auc'
# *   Discrimination Threshold     - 'threshold'
# *   Precision Recall Curve       - 'pr'
# *   Confusion Matrix             - 'confusion_matrix'
# *   Class Prediction Error       - 'error'
# *   Classification Report        - 'class_report'
# *   Decision Boundary            - 'boundary'
# *   Recursive Feat. Selection    - 'rfe'
# *   Learning Curve               - 'learning'
# *   Manifold Learning            - 'manifold'
# *   Calibration Curve            - 'calibration'
# *   Validation Curve             - 'vc'
# *   Dimension Learning           - 'dimension'
# *   Feature Importance           - 'feature'
# *   Model Hyperparameter         - 'parameter'

# %% [markdown]
# ---
# ### **5.1 Create RandomForest model or any other model**
# ---

# %%
rfModel = create_model('rf')

# %% [markdown]
# ---
# ### **5.2 Create "Confusion Matrix"**
# ---

# %%
plot_model(rfModel, plot='confusion_matrix')

# %% [markdown]
# ---
# ### **5.3 Plot the "learning curve"**
# ---

# %%
plot_model(rfModel, plot='learning')

# %% [markdown]
# ---
# ### **5.4 Plot the "AUC Curve" (Area Under the Curve)**
# ---

# %%
plot_model(rfModel, plot='auc')

# %% [markdown]
# ---
# ### **5.5 Plot the "Decision Boundary"**
# ---

# %%
plot_model(rfModel, plot='boundary')

# %% [markdown]
# ---
# ### **5.6 Get the model "parameters"**
# ---

# %%
plot_model(rfModel, plot='parameter')

# %% [markdown]
# ---
# ### **5.7 Explore the more parameters of "plot_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html#pycaret.classification.plot_model" target="_blank"> Click Here </a>**

# %% [markdown]
# ---
# # **6. Feature Importance**
# ---
# ### **6.1 Feature Importance using "Random Forest"**

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %% [markdown]
# ---
# ### **6.2 Feature Importance using "Extra Trees Regressor"**
# ---

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %% [markdown]
# ---
# ### **6.3 Feature Importance using "Decision Tree"**
# ---

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %% [markdown]
# ---
# # **7. Tune/Optimize the model performance**
# ---
# ### **7.1 Train "Decision Tree" with default parameters**

# %%
dtModel = create_model('dt')

# %% [markdown]
# #### **Get the "parameters" of Decision Tree**

# %%
plot_model(dtModel, plot='parameter')

# %% [markdown]
# ---
# ### **7.2 Tune "Decision Tree" model**
# ---

# %%
dtModelTuned = tune_model(dtModel, n_iter=50)

# %% [markdown]
# #### **Get the "tuned parameters" of Decision Tree**

# %%
plot_model(dtModelTuned, plot='parameter')

# %% [markdown]
# ---
# ### **7.3 Explore more parameters of "tune_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html#pycaret.classification.tune_model" target="_blank"> Click Here </a>**

# %% [markdown]
# ---
# # **8. AutoML - Advanced Machine Learning**
# ---
#
# - Select n Best Models:
#   - Ensemble, Stacking, Begging, Blending
#   - Auto tune the best n models
#
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html#pycaret.classification.automl" target="_blank">Click Here</a>**

# %% [markdown]
# ---
# # **9. Deploy the model on AWS / Azure**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html#pycaret.classification.deploy_model" target="_blank">Click Here</a>**
